# %% [markdown]
# # Stock Exchange Data
# This dataset consists of stock exchange data since 1965 for several indexes. It contains the daily stock prices along with the volume traded each day.

# %% [markdown]
# __Importing the necessary Packages__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# _Loading the Data_

# %%
df = pd.read_csv('stock_data.csv', index_col = None)
df
# Out:
#           Index        Date          Open          High           Low  \
# 0           HSI  1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI  1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI  1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI  1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI  1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...         ...           ...           ...           ...
# 104219  J203.JO  2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO  2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO  2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO  2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO  2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049     0.0   333.879006
# ...

# %% [markdown]
# __Let's Get Some Information About Our Data__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104224 entries, 0 to 104223
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Index      104224 non-null  object
#  1   Date       104224 non-null  object
#  2   Open       104224 non-null  float64
#  3   High       104224 non-null  float64
#  4   Low        104224 non-null  float64
#  5   Close      104224 non-null  float64
#  6   Adj Close  104224 non-null  float64
#  7   Volume     104224 non-null  float64
#  8   CloseUSD   104224 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 7.2+ MB

# %%
df.columns
# Out:
# Index(['Index', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'CloseUSD'],
#       dtype='object')

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
# Converting Date from object type to date-time type 
df['Date'] = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104224 entries, 0 to 104223
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Index      104224 non-null  object
#  1   Date       104224 non-null  datetime64[ns]
#  2   Open       104224 non-null  float64
#  3   High       104224 non-null  float64
#  4   Low        104224 non-null  float64
#  5   Close      104224 non-null  float64
#  6   Adj Close  104224 non-null  float64
#  7   Volume     104224 non-null  float64
#  8   CloseUSD   104224 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 7.2+ MB

# %%
# Checking for Null and Duplicated Values

# %%
df.isna().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# CloseUSD     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (104224, 9)

# %% [markdown]
# __Exploratory Data Analysis__

# %%
# Checking for summary statistics of our data

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  104224.000000  104224.000000  104224.000000  104224.000000
# mean     8015.353334    8063.324234    7962.581120    8014.366642
# std      9140.563404    9196.575802    9082.767802    9140.609758
# min        54.869999      54.869999      54.869999      54.869999
# 25%      2046.887756    2057.213990    2037.185943    2047.506470
# 50%      5772.140137    5812.764892    5725.199951    5773.710205
# 75%     10487.377445   10552.179690   10416.092287   10488.622560
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume       CloseUSD
# count  104224.000000  1.042240e+05  104224.000000
# mean     8014.161269  1.347646e+09    3046.729177
# std      9140.720456  4.427662e+09    3747.865623
# min        54.869999  0.000000e+00      10.204900
# 25%      2047.358490  0.000000e+00     320.460898
# 50%      5773.710205  9.529000e+05    1371.598486
# ...

# %%
df
# Out:
#           Index       Date          Open          High           Low  \
# 0           HSI 1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI 1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI 1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI 1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI 1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...        ...           ...           ...           ...
# 104219  J203.JO 2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO 2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO 2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO 2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO 2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049     0.0   333.879006
# ...

# %%
df['Index'].value_counts()
# Out:
# NYA          13947
# N225         13874
# IXIC         12690
# GSPTSE       10526
# HSI           8492
# GDAXI         8438
# SSMI          7671
# TWII          5869
# 000001.SS     5791
# 399001.SZ     5760
# N100          5474
# NSEI          3346
# J203.JO       2346
# Name: Index, dtype: int64

# %% [markdown]
# __Using the actual name of the stocks and putting it in a dictionary__

# %%
index_name = {'NYA':'New York Stock Exchange', 'N225':'Nikkei 225',
              'IXIC':'Nasdaq', 'GSPTSE':'S&P TSX', 'HSI':'Heng Seng Index',
              'GDAXI':'Dax Performance Index', 'SSMI':'Swiss Market Index', 'TWII':'Taiwan Weighted Index',
              '000001.SS':'Sanghai Stock Exchange', '399001.SZ':'Shenzen Component', 'N100':'Euronext 100',
              'NSEI':'Nifty 50', 'J203JO':'Johannesburg Index'}

# %%
index_name
# Out:
# {'NYA': 'New York Stock Exchange',
#  'N225': 'Nikkei 225',
#  'IXIC': 'Nasdaq',
#  'GSPTSE': 'S&P TSX',
#  'HSI': 'Heng Seng Index',
#  'GDAXI': 'Dax Performance Index',
#  'SSMI': 'Swiss Market Index',
#  'TWII': 'Taiwan Weighted Index',
#  '000001.SS': 'Sanghai Stock Exchange',
#  '399001.SZ': 'Shenzen Component',
#  'N100': 'Euronext 100',
#  'NSEI': 'Nifty 50',
#  'J203JO': 'Johannesburg Index'}

# %%
for name in index_name:
    print(name)
# Out:
# NYA
# N225
# IXIC
# GSPTSE
# HSI
# GDAXI
# SSMI
# TWII
# 000001.SS
# 399001.SZ
# N100
# NSEI
# J203JO

# %%
df['index_name']= df['Index'].replace(index_name)
df.head()
# Out:
#   Index       Date         Open         High          Low        Close  \
# 0   HSI 1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI 1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI 1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI 1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI 1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD       index_name
# 0  2568.300049     0.0  333.879006  Heng Seng Index
# 1  2540.100098     0.0  330.213013  Heng Seng Index
# 2  2552.399902     0.0  331.811987  Heng Seng Index
# 3  2583.899902     0.0  335.906987  Heng Seng Index
# 4  2607.100098     0.0  338.923013  Heng Seng Index

# %%
df.groupby(['Index','index_name']).sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\2931703255.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Index','index_name']).sum()
#                                            Open          High           Low  \
# Index     index_name
# 000001.SS Sanghai Stock Exchange   1.378958e+07  1.391069e+07  1.366066e+07
# 399001.SZ Shenzen Component        4.589764e+07  4.638474e+07  4.540050e+07
# GDAXI     Dax Performance Index    4.991540e+07  5.026467e+07  4.952871e+07
# GSPTSE    S&P TSX                  8.516699e+07  8.555560e+07  8.471628e+07
# HSI       Heng Seng Index          1.291324e+08  1.299584e+08  1.281532e+08
# IXIC      Nasdaq                   2.518999e+07  2.535526e+07  2.499910e+07
# J203.JO   J203.JO                  1.194037e+08  1.201627e+08  1.186836e+08
# ...

# %%
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')
# %matplotlib inline

#df.set_index('Date', inplace = True)
df['Close'].plot(title = 'Stock Price Trend')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y, "o:g", ms = 10, mec='b',mfc='m') #"r" is the colour red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')

# %%
sns.set(style= 'whitegrid', font_scale = 1.00)
sns.set_palette('coolwarm', 4)
sns.relplot(x= 'Date', y = 'CloseUSD', kind= 'line', data = df, col= 'index_name', col_wrap= 4)

plt.show()

# %%
df.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999958  0.999942  0.999904   0.999904  0.129090
# High       0.999958  1.000000  0.999929  0.999954   0.999954  0.128926
# Low        0.999942  0.999929  1.000000  0.999958   0.999958  0.128964
# Close      0.999904  0.999954  0.999958  1.000000   1.000000  0.128971
# Adj Close  0.999904  0.999954  0.999958  1.000000   1.000000  0.128976
# Volume     0.129090  0.128926  0.128964  0.128971   0.128976  1.000000
# CloseUSD   0.187904  0.187606  0.188190  0.187979   0.187980  0.506375
#
#            CloseUSD
# Open       0.187904
# High       0.187606
# Low        0.188190
# Close      0.187979
# ...

# %%
plt.figure(figsize = (9,9))
cor = df.corr()
sns.heatmap(cor,annot =True, cmap ='YlGnBu')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\2542350093.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = df.corr()

# %% [markdown]
# _Let's take a closer look at the stocks that underperformed_
#
# _We can deduce that most of the stock that underperfoormed are from the Asian Region_

# %%
Asian_market = df[df['Index']. isin (['N225', 'Nikkei 225', 'TWII', '000001.SS'])]
Asian_market
# Out:
#             Index       Date          Open          High           Low  \
# 35129   000001.SS 1997-07-02   1255.909058   1261.571045   1147.331055
# 35130   000001.SS 1997-07-03   1194.676025   1194.676025   1149.939941
# 35131   000001.SS 1997-07-04   1138.921021   1163.249023   1124.776001
# 35132   000001.SS 1997-07-07   1161.707031   1163.447021   1085.572021
# 35133   000001.SS 1997-07-08   1092.798950   1115.432983   1066.043945
# ...           ...        ...           ...           ...           ...
# 101873       TWII 2021-05-25  16444.750000  16657.599610  16444.750000
# 101874       TWII 2021-05-26  16645.169920  16706.289060  16523.230470
# 101875       TWII 2021-05-27  16591.699220  16601.609380  16419.419920
# 101876       TWII 2021-05-28  16690.039060  16889.009770  16690.039060
# 101877       TWII 2021-05-31  16948.470700  17113.330080  16939.910160
#
#                Close     Adj Close     Volume    CloseUSD  \
# ...

# %%
Asian_market.head()
# Out:
#            Index       Date         Open         High          Low  \
# 35129  000001.SS 1997-07-02  1255.909058  1261.571045  1147.331055
# 35130  000001.SS 1997-07-03  1194.676025  1194.676025  1149.939941
# 35131  000001.SS 1997-07-04  1138.921021  1163.249023  1124.776001
# 35132  000001.SS 1997-07-07  1161.707031  1163.447021  1085.572021
# 35133  000001.SS 1997-07-08  1092.798950  1115.432983  1066.043945
#
#              Close    Adj Close  Volume    CloseUSD              index_name
# 35129  1199.061035  1199.061035     0.0  191.849766  Sanghai Stock Exchange
# 35130  1150.623047  1150.623047     0.0  184.099688  Sanghai Stock Exchange
# 35131  1159.342041  1159.342041     0.0  185.494727  Sanghai Stock Exchange
# 35132  1096.818970  1096.818970     0.0  175.491035  Sanghai Stock Exchange
# 35133  1109.666016  1109.666016     0.0  177.546563  Sanghai Stock Exchange

# %%
Asian_market.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\124193508.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Asian_market.corr()
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999935  0.999910  0.999857   0.999857  0.295889
# High       0.999935  1.000000  0.999874  0.999928   0.999928  0.296716
# Low        0.999910  0.999874  1.000000  0.999929   0.999929  0.294976
# Close      0.999857  0.999928  0.999929  1.000000   1.000000  0.295871
# Adj Close  0.999857  0.999928  0.999929  1.000000   1.000000  0.295871
# Volume     0.295889  0.296716  0.294976  0.295871   0.295871  1.000000
# CloseUSD  -0.030668 -0.029982 -0.031475 -0.030548  -0.030548 -0.230038
#
#            CloseUSD
# Open      -0.030668
# High      -0.029982
# Low       -0.031475
# ...

# %%
Asian_market['Movement'] = Asian_market['High']-Asian_market['Low']
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\4200483992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_market['Movement'] = Asian_market['High']-Asian_market['Low']
#           Index       Date          Open          High           Low  \
# 0           HSI 1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI 1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI 1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI 1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI 1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...        ...           ...           ...           ...
# ...

# %%
Asian_market['index_name']
# Out:
# 35129     Sanghai Stock Exchange
# 35130     Sanghai Stock Exchange
# 35131     Sanghai Stock Exchange
# 35132     Sanghai Stock Exchange
# 35133     Sanghai Stock Exchange
#                    ...
# 101873     Taiwan Weighted Index
# 101874     Taiwan Weighted Index
# 101875     Taiwan Weighted Index
# 101876     Taiwan Weighted Index
# 101877     Taiwan Weighted Index
# Name: index_name, Length: 25534, dtype: object

# %%
Asian_market.sort_values('Date')
# Out:
#             Index       Date          Open          High           Low  \
# 40920        N225 1965-01-05   1257.719971   1257.719971   1257.719971
# 40921        N225 1965-01-06   1263.989990   1263.989990   1263.989990
# 40922        N225 1965-01-07   1274.270020   1274.270020   1274.270020
# 40923        N225 1965-01-08   1286.430054   1286.430054   1286.430054
# 40924        N225 1965-01-12   1288.540039   1288.540039   1288.540039
# ...           ...        ...           ...           ...           ...
# 40919   000001.SS 2021-05-31   3600.070068   3615.659912   3580.649902
# 101877       TWII 2021-05-31  16948.470700  17113.330080  16939.910160
# 54791        N225 2021-06-01  28998.650390  29075.470700  28611.250000
# 54792        N225 2021-06-02  28730.810550  29003.550780  28565.830080
# 54793        N225 2021-06-03  28890.390630  29157.160160  28879.150390
#
#                Close     Adj Close      Volume    CloseUSD  \
# ...

# %%
Asian_market ['Month'] = Asian_market['Date'].dt.month
Asian_market
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\3263167693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_market ['Month'] = Asian_market['Date'].dt.month
#             Index       Date          Open          High           Low  \
# 35129   000001.SS 1997-07-02   1255.909058   1261.571045   1147.331055
# 35130   000001.SS 1997-07-03   1194.676025   1194.676025   1149.939941
# 35131   000001.SS 1997-07-04   1138.921021   1163.249023   1124.776001
# 35132   000001.SS 1997-07-07   1161.707031   1163.447021   1085.572021
# 35133   000001.SS 1997-07-08   1092.798950   1115.432983   1066.043945
# ...           ...        ...           ...           ...           ...
# ...

# %%
Asian_market.groupby(['Month'])['Close'].mean().sort_values().plot(kind= 'barh', color='blue')

plt.xlabel('Month')
plt.ylabel('Average Movement')
plt.title('Most Volatile  Months ')
plt.show()

# %%
sns.pairplot(data=Asian_market,palette="rainbow",hue='Close')

# %%
# Calculate daily returns
Asian_market['Daily_return'] = Asian_market['CloseUSD'].pct_change()
Asian_market
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\365213041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_market['Daily_return'] = Asian_market['CloseUSD'].pct_change()
#             Index       Date          Open          High           Low  \
# 35129   000001.SS 1997-07-02   1255.909058   1261.571045   1147.331055
# 35130   000001.SS 1997-07-03   1194.676025   1194.676025   1149.939941
# 35131   000001.SS 1997-07-04   1138.921021   1163.249023   1124.776001
# 35132   000001.SS 1997-07-07   1161.707031   1163.447021   1085.572021
# 35133   000001.SS 1997-07-08   1092.798950   1115.432983   1066.043945
# ...           ...        ...           ...           ...           ...
# ...

# %%
plt.figure(figsize = (10,5))
sns.jointplot(x='Date',y='CloseUSD',data=Asian_market,kind='reg')
#Asian_market['daily_return'].jointplot()
#plt.title('Daily Returns')
#plt.xlabel('Date')
#plt.ylabel('Percentage Change')
#plt.grid(True)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.figure(figsize = (10,5))
# ----> 2 sns.jointplot(x='Date',y='CloseUSD',data=Asian_market,kind='reg')
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2324, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2321     grid.plot_marginals(histplot, **marginal_kws)
#    2323     joint_kws.setdefault("color", color)
# -> 2324     grid.plot_joint(regplot, **joint_kws)
#    2326 elif kind.startswith("resid"):
#    2328     joint_kws.setdefault("color", color)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:1826, in JointGrid.plot_joint(self, func, **kwargs)
#    1823     self._inject_kwargs(func, kwargs, self._hue_params)
# ...

# %%
sns.boxplot(x= 'daily_return',data=Asian_market)
# Out:
# <Axes: xlabel='daily_return'>

# %%
# Find the date with the highest closing price
max_close_date= Asian_market.loc[Asian_market['CloseUSD'].idxmax(), 'Date']
max_close_date
# Out:
# Timestamp('2007-10-16 00:00:00')

# %%
# Find the Date with the lowest closing price

min_close_date= Asian_market.loc[Asian_market['CloseUSD'].idxmin(), 'Date']
min_close_date
# Out:
# Timestamp('1965-07-12 00:00:00')

# %%
plt.figure(figsize = (10,6))
plt.plot(['Max Close', 'Min Close'], [Asian_market['CloseUSD'].max(), Asian_market['CloseUSD'].min()])
plt.title('Highest and Lowest Closing Prices')
plt.ylabel('Close Price (USD)')
plt.show()

# %% [markdown]
# ### Volume Analysis

# %%
# Calculating the average volume

avg_volume = Asian_market['Volume'].mean()
avg_volume
# Out:
# 22194299.151797604

# %%
# Finding days with Volume greater than average

high_volume_days = Asian_market[Asian_market['Volume'] > avg_volume]['Date']
high_volume_days
# Out:
# 50146   2002-06-10
# 50147   2002-06-11
# 50148   2002-06-12
# 50149   2002-06-13
# 50150   2002-06-14
#            ...
# 54788   2021-05-27
# 54789   2021-05-28
# 54790   2021-05-31
# 54791   2021-06-01
# 54792   2021-06-02
# Name: Date, Length: 4633, dtype: datetime64[ns]

# %%
plt.figure(figsize=(10,5))
Asian_market['Volume'].plot()
plt.title('Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(data=Asian_market, x='Date', y='Volume',color ='g')
plt.title('Volume Over Time')
plt.grid(True)
plt.show()

# %%
plt.plot('Date','Volume', "o:g", ms = 10, mec='b',mfc='m') #"r" is the colour red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
# Out:
# Text(0.5, 1.0, 'String Title Here')

# %%
sns.barplot(x='Date',y='Volume',data=Asian_market)
# Out:
# <Axes: xlabel='Date', ylabel='Volume'>

# %% [markdown]
# ### Trend Analysis

# %%
# Cacuating Moving Average

Asian_market['MA_50']= Asian_market['CloseUSD'].rolling(window= 50).mean()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\1512424065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_market['MA_50']= Asian_market['CloseUSD'].rolling(window= 50).mean()

# %%
# Determine the trend based on moving average
Asian_market['trend'] = np.where(Asian_market['CloseUSD'] > Asian_market['Movement'], 'Up', 'Down')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9820\3256254490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_market['trend'] = np.where(Asian_market['CloseUSD'] > Asian_market['Movement'], 'Up', 'Down')

# %%
plt.figure(figsize=(10,5))
plt.plot(Asian_market['Date'], Asian_market['CloseUSD'], label = 'Close Price')
plt.plot(Asian_market['Date'], Asian_market['MA_50'], label= '50-day Moving Average')
plt.title('Closing Price and 50-day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Volatile Analysis

# %%
# Calculating daily price range (high - low)
Asian_market['Movement']
#Asian_market['price_range'] = Asian_market['High'] - Asian_market['Low']
# Out:
# 35129     114.239990
# 35130      44.736084
# 35131      38.473022
# 35132      77.875000
# 35133      49.389038
#              ...
# 101873    212.849610
# 101874    183.058590
# 101875    182.189460
# 101876    198.970710
# 101877    173.419920
# Name: Movement, Length: 25534, dtype: float64

# %%
# Calculating average daily price range

avg_price_range = Asian_market['Movement'].mean()

# %%
plt.figure(figsize=(10,5))
Asian_market['Movement'].plot()
plt.title('Average Daily Price Range Over Time')
plt.xlabel('Date')
plt.ylabel('Price Range')
plt.grid(True)
plt.show()
