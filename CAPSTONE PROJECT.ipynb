# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HOMELINC (Responses) - Form Responses 1.csv")

# %%
df.head()
# Out:
#          Timestamp                   Email Address    Age City/State  \
# 0  3/10/2024 18:41          atinukesanni@gmail.com  25-34       Osun
# 1  3/10/2024 20:48            dayollukas@gmail.com  18-24   Plateau
# 2  3/11/2024 19:36       jochebedmshelia@gmail.com  25-34     Kaduna
# 3  3/11/2024 19:37  HelenUmeano@womentechsters.org  25-34    Kaduna
# 4  3/11/2024 19:46           diegoguddie@gmail.com  25-34      Osun
#
#              Employment Status Are you currently renting a property?  \
# 0                     Employed                                   Yes
# 1  Self- employed / Freelancer                                    No
# 2  Self- employed / Freelancer                                   Yes
# 3  Self- employed / Freelancer                                    No
# 4                      Student                                   Yes
#
#   How often do you search for rental properties?  \
# 0                                     Very often
# ...

# %%
df.rename(columns={'Do you find map-based search features helpful when looking for rental properties?': 'Enhanced Rental Property Search with Map Features'
                  }, inplace=True)

# %%
df.tail()
# Out:
#           Timestamp              Email Address    Age           City/State  \
# 68  3/20/2024 23:36  goodnessjoel368@gmail.com  18-24  Jos, plateau state
# 69  3/20/2024 23:41    dawangteresa1@gmail.com  18-24                  Jos
# 70   3/21/2024 5:14     selzingmusa1@gmail.com  18-24        Jos, Nigeria
# 71  3/21/2024 10:46   janemarkella05@gmail.com  18-24   Jos Plateau State
# 72  3/23/2024 16:50      daredauda92@gmail.com  25-34               Osogbo
#
#               Employment Status Are you currently renting a property?  \
# 68                      Student                                    No
# 69                      Student                                    No
# 70                      Student                                   Yes
# 71  Self- employed / Freelancer                                    No
# 72                     Employed                                    No
#
#    How often do you search for rental properties?  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email Address', 'Age', 'City/State', 'Employment Status',
#        'Are you currently renting a property?',
#        'How often do you search for rental properties?',
#        'Have you ever missed a property inspection due to a lack of timely notifications? ',
#        'Rent Reminders Preference',
#        'Enhanced Rental Property Search with Map Features',
#        'How would you rate the availability of affordable housing options in Nigeria?',
#        'What are the biggest challenges you face when searching for rental accommodations in Nigeria?',
#        'Nigeria Housing Satisfaction',
#        'Would You Be Intrested In Exploring Alternative Housing, solutions',
#        'Would you be open to the idea of paying monthly rents?',
#        'Nigeria Property Investment',
#        'What features would you find most helpful in a rental housing platform? (Select all that apply)',
# ...

# %%
df.shape
# Out:
# (73, 19)

# %%
df.describe()
# Out:
#               Timestamp           Email Address    Age City/State  \
# count                73                      73     73         73
# unique               70                      73      5         48
# top     3/11/2024 20:04  atinukesanni@gmail.com  25-34     Lagos
# freq                  3                       1     50          7
#
#        Employment Status Are you currently renting a property?  \
# count                 73                                    73
# unique                 4                                     2
# top             Employed                                   Yes
# freq                  35                                    41
#
#        How often do you search for rental properties?  \
# count                                              73
# unique                                              3
# top                                            Rarely
# freq                                               39
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                          0
# Email Address                                                                                      0
# Age                                                                                                0
# City/State                                                                                         0
# Employment Status                                                                                  0
# Are you currently renting a property?                                                              0
# How often do you search for rental properties?                                                     0
# Have you ever missed a property inspection due to a lack of timely notifications?                  0
# Rent Reminders Preference                                                                          0
# ...

# %%
import pandas as pd

# %%
cleaned_df = df.dropna()

# %%
print(cleaned_df)
# Out:
#           Timestamp                   Email Address    Age  \
# 0   3/10/2024 18:41          atinukesanni@gmail.com  25-34
# 1   3/10/2024 20:48            dayollukas@gmail.com  18-24
# 2   3/11/2024 19:36       jochebedmshelia@gmail.com  25-34
# 3   3/11/2024 19:37  HelenUmeano@womentechsters.org  25-34
# 4   3/11/2024 19:46           diegoguddie@gmail.com  25-34
# ..              ...                             ...    ...
# 68  3/20/2024 23:36       goodnessjoel368@gmail.com  18-24
# 69  3/20/2024 23:41         dawangteresa1@gmail.com  18-24
# 70   3/21/2024 5:14          selzingmusa1@gmail.com  18-24
# 71  3/21/2024 10:46        janemarkella05@gmail.com  18-24
# 72  3/23/2024 16:50           daredauda92@gmail.com  25-34
#
#              City/State            Employment Status  \
# 0                  Osun                     Employed
# 1              Plateau   Self- employed / Freelancer
# 2                Kaduna  Self- employed / Freelancer
# ...

# %%
for column in df.columns:
    print(column, df[column].unique())
# Out:
# Timestamp ['3/10/2024 18:41' '3/10/2024 20:48' '3/11/2024 19:36' '3/11/2024 19:37'
#  '3/11/2024 19:46' '3/11/2024 19:47' '3/11/2024 19:55' '3/11/2024 19:57'
#  '3/11/2024 20:04' '3/11/2024 20:05' '3/11/2024 20:06' '3/11/2024 20:14'
#  '3/11/2024 20:18' '3/11/2024 20:25' '3/11/2024 20:26' '3/11/2024 20:29'
#  '3/11/2024 20:35' '3/11/2024 20:44' '3/11/2024 21:02' '3/11/2024 21:05'
#  '3/11/2024 22:37' '3/11/2024 22:42' '3/11/2024 22:47' '3/11/2024 22:56'
#  '3/11/2024 22:57' '3/11/2024 23:11' '3/11/2024 23:17' '3/12/2024 0:13'
#  '3/12/2024 0:22' '3/12/2024 0:57' '3/12/2024 4:25' '3/12/2024 4:47'
#  '3/12/2024 6:11' '3/12/2024 6:57' '3/12/2024 7:25' '3/12/2024 8:11'
#  '3/12/2024 8:44' '3/12/2024 8:53' '3/12/2024 9:22' '3/12/2024 9:23'
#  '3/12/2024 12:00' '3/12/2024 12:06' '3/12/2024 12:28' '3/12/2024 15:00'
#  '3/12/2024 16:24' '3/12/2024 16:59' '3/13/2024 0:41' '3/13/2024 10:18'
#  '3/13/2024 10:19' '3/13/2024 19:14' '3/13/2024 22:22' '3/14/2024 9:50'
# ...

# %%
df.describe()
# Out:
#               Timestamp           Email Address    Age City/State  \
# count                73                      73     73         73
# unique               70                      73      5         48
# top     3/11/2024 20:04  atinukesanni@gmail.com  25-34     Lagos
# freq                  3                       1     50          7
#
#        Employment Status Are you currently renting a property?  \
# count                 73                                    73
# unique                 4                                     2
# top             Employed                                   Yes
# freq                  35                                    41
#
#        How often do you search for rental properties?  \
# count                                              73
# unique                                              3
# top                                            Rarely
# freq                                               39
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#          Timestamp                   Email Address    Age City/State  \
# 0  3/10/2024 18:41          atinukesanni@gmail.com  25-34       Osun
# 1  3/10/2024 20:48            dayollukas@gmail.com  18-24   Plateau
# 2  3/11/2024 19:36       jochebedmshelia@gmail.com  25-34     Kaduna
# 3  3/11/2024 19:37  HelenUmeano@womentechsters.org  25-34    Kaduna
# 4  3/11/2024 19:46           diegoguddie@gmail.com  25-34      Osun
#
#              Employment Status Are you currently renting a property?  \
# 0                     Employed                                   Yes
# 1  Self- employed / Freelancer                                    No
# 2  Self- employed / Freelancer                                   Yes
# 3  Self- employed / Freelancer                                    No
# 4                      Student                                   Yes
#
#   How often do you search for rental properties?  \
# 0                                     Very often
# ...

# %%
import seaborn as sns

# %%
base_color = sns.color_palette()[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 19 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Timestamp                                                                                        73 non-null     object
#  1   Email Address                                                                                    73 non-null     object
#  2   Age                                                                                              73 non-null     object
#  3   City/State                                                                                       73 non-null     object
#  4   Employment Status                                                                                73 non-null     object
# ...

# %%
df.rename(columns={'Do you find map-based search features helpful when looking for rental properties?': 'Enhanced Rental Property Search with Map Features'
                  }, inplace=True)

# %%
df.rename(columns={'Do you find map-based search features helpful when looking for rental properties?': 'Enhanced Rental Property Search with Map Features'
                  }, inplace=True)

# %%
df.drop(columns=['Timestamp', 'Email Address'], axis=1, inplace=True)

# %%
df
# Out:
#       Age           City/State            Employment Status  \
# 0   25-34                 Osun                     Employed
# 1   18-24             Plateau   Self- employed / Freelancer
# 2   25-34               Kaduna  Self- employed / Freelancer
# 3   25-34              Kaduna   Self- employed / Freelancer
# 4   25-34                Osun                       Student
# ..    ...                  ...                          ...
# 68  18-24  Jos, plateau state                       Student
# 69  18-24                  Jos                      Student
# 70  18-24        Jos, Nigeria                       Student
# 71  18-24   Jos Plateau State   Self- employed / Freelancer
# 72  25-34               Osogbo                     Employed
#
#    Are you currently renting a property?  \
# 0                                    Yes
# 1                                     No
# 2                                    Yes
# 3                                     No
# ...

# %%
import seaborn as sns

# %%
sns.histplot(x=df['Age'], kde=True, color='orange')
plt.title('AGE DISTRIBUTION')
plt.savefig('Age visual');

# %%
sns.countplot(x=df['Employment Status'], hue=df['Age'], palette='Blues');
plt.title('Employment Trend Across Age Goups')
plt.savefig('Employment Status visual');

# %%
sns.countplot(x=df['Are you currently renting a property?'], hue=df['Age'], palette='Oranges');
plt.title('Renting Status and Age')
plt.savefig('Renting Status');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.countplot(x=df['Are you currently renting a property?'], hue=df['Age'], palette='Oranges');
#       2 plt.title('Renting Status and Age')
#       3 plt.savefig('Renting Status')
#
# NameError: name 'sns' is not defined

# %%
sns.countplot(x=df['Are you currently renting a property?'], hue=df['Employment Status'], palette='Blues');
plt.title('Renting Status')
plt.savefig('Renting Status');

# %%
sns.countplot(x=df['How often do you search for rental properties?'], hue=df['Employment Status'], palette='Oranges');
plt.title('Rental Property Search Frequency')
plt.savefig('property search');

# %%
sns.countplot(x=df['Enhanced Rental Property Search with Map Features'], hue=df['Employment Status'], palette='Blues');
plt.title('Rental Property Search With Map')
plt.savefig('map visuals');

# %%
sns.countplot(x=df['Would you be open to the idea of paying monthly rents?'], hue=df['Employment Status'], palette='Oranges');
plt.title('Payment Of Monthly Rent')
plt.savefig('Payment visuals');

# %%
sns.countplot(x=df['Nigeria Housing Satisfaction'], hue=df['Employment Status'], palette='Oranges');
plt.title('Nigeria Housing Satisfaction')
plt.savefig('Satisfaction Visuals');

# %%
sns.countplot(x=df['Nigeria Property Investment'], hue=df['Employment Status'], palette='Blues')
plt.title('Likelihood of Utilizing Property Investment Platform in Nigeria')
plt.savefig('investment visuals');

# %%
sns.countplot(x=df['Rent Reminders Preference'], hue=df['Employment Status'], palette='Oranges')
plt.title('Rent Reminder Preference')
plt.savefig('Reminder Visuals');

# %%
sns.countplot(x=df['How satisfied are you with the transparency of rental listings in Nigeria?'], hue=df['Employment Status'], palette='Blues');
plt.title('Satisfaction Transparency OF Rental Listing In Nigeria')
plt.savefig('Transparency visuals');

# %%
sns.countplot(x=df['Recommendation Likelihood For Affordable Rental Platform'], hue=df['Employment Status'], palette='Oranges');
plt.title('Recommendation For Affordable Rental Platform')
plt.savefig('Recommendation Visuals');
